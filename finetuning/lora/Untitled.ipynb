# %%
print(config.BASE_MODEL_NAME)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 from config import MAX_LENGTH, MAX_NEW_TOKENS, TEMPERATURE, TOP_P, DO_SAMPLE, GENERATION_MODEL_PATH, BASE_MODEL_NAME, REPETITION_PENALTY
#       3 print(config.BASE_MODEL_NAME)
#
# ImportError: cannot import name 'MAX_LENGTH' from 'config' (/home/jovyan/digdir-camp-2025-desKI/finetuning/lora/config.py)

# %%
print(config.__file__)
# Out:
# /home/jovyan/digdir-camp-2025-desKI/app/config.py

# %%
print(config.MAX_NEW_TOKENS)
# Out:
# 1024
